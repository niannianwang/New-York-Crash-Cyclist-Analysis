# %% [markdown]
# ### Introduction

# %% [markdown]
# Original motivation to explore this dataset is because of the post I saw from New York Times on instagram. (link: https://www.instagram.com/p/C4KFCSELMr0/?utm_source=ig_web_copy_link&igsh=MzRlODBiNWFlZA%3D%3D) The posts states how e-bikes are having more serious accidents than traditional bikes.
#
# After reading the post, my immediate question was that does e-bikes having more accidents than traditional bikes generally due to the increase in usage of e-bikes. However, this information was not provided and want to investigate further. I found a relevant data set from NYC OpenData on crash cyclists https://data.cityofnewyork.us/Public-Safety/Crash-Cyclist-2020/2kbb-e72t/about_data. When I accessed the dataset, it is updated to March 26, 2024.

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('Crash-Cyclist-2020_20240327.csv')

# %%
data
# Out:
#        CRASH DATE CRASH TIME    BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 0      12/14/2021      12:54   BROOKLYN   11217.0  40.687534 -73.977500
# 1      12/14/2021      16:25        NaN       NaN  40.784615 -73.953964
# 2      04/24/2022      15:35  MANHATTAN   10019.0  40.767242 -73.986206
# 3      12/09/2021      20:20   BROOKLYN   11223.0  40.592070 -73.962990
# 4      12/09/2021      23:15   BROOKLYN   11218.0  40.640835 -73.989670
# ...           ...        ...        ...       ...        ...        ...
# 21096  02/14/2020      22:44        NaN       NaN  40.710907 -73.951650
# 21097  10/22/2022       8:55   BROOKLYN   11249.0  40.712860 -73.965790
# 21098  11/06/2022      17:30  MANHATTAN   10022.0  40.762733 -73.973400
# 21099  09/21/2023       8:01        NaN       NaN  40.678818 -73.965350
# 21100  10/13/2023      20:40   BROOKLYN   11214.0  40.592495 -73.984440
#
#                       LOCATION                    ON STREET NAME  \
# 0        (40.687534, -73.9775)                     FULTON STREET
# 1      (40.784615, -73.953964)                    EAST 93 STREET
# 2      (40.767242, -73.986206)                    WEST 56 STREET
# 3        (40.59207, -73.96299)                     EAST 7 STREET
# 4       (40.640835, -73.98967)                         12 AVENUE
# ...                        ...                               ...
# 21096   (40.710907, -73.95165)  BORINQUEN PLACE
# 21097    (40.71286, -73.96579)                    SOUTH 4 STREET
# 21098    (40.762733, -73.9734)                               NaN
# 21099   (40.678818, -73.96535)                     BERGEN STREET
# 21100   (40.592495, -73.98444)                  STILLWELL AVENUE
#
#         CROSS STREET NAME           OFF STREET NAME  ...  \
# 0      SAINT FELIX STREET                       NaN  ...
# 1                     NaN                       NaN  ...
# 2                9 AVENUE                       NaN  ...
# 3         CRAWFORD AVENUE                       NaN  ...
# 4               41 STREET                       NaN  ...
# ...                   ...                       ...  ...
# 21096                 NaN                       NaN  ...
# 21097        WYTHE AVENUE                       NaN  ...
# 21098                 NaN  11        EAST 57 STREET  ...
# 21099                 NaN                       NaN  ...
# 21100       BAY 46 STREET                       NaN  ...
#
#         CONTRIBUTING FACTOR VEHICLE 2  CONTRIBUTING FACTOR VEHICLE 3  \
# 0                         Unspecified                            NaN
# 1      Driver Inattention/Distraction                            NaN
# 2                         Unspecified                            NaN
# 3                         Unspecified                            NaN
# 4      Driver Inattention/Distraction                            NaN
# ...                               ...                            ...
# 21096                     Unspecified                    Unspecified
# 21097                     Unspecified                            NaN
# 21098  Driver Inattention/Distraction                            NaN
# 21099  Passing or Lane Usage Improper                            NaN
# 21100                     Unspecified                            NaN
#
#        CONTRIBUTING FACTOR VEHICLE 4  CONTRIBUTING FACTOR VEHICLE 5  \
# 0                                NaN                            NaN
# 1                                NaN                            NaN
# 2                                NaN                            NaN
# 3                                NaN                            NaN
# 4                                NaN                            NaN
# ...                              ...                            ...
# 21096                    Unspecified                    Unspecified
# 21097                            NaN                            NaN
# 21098                            NaN                            NaN
# 21099                            NaN                            NaN
# 21100                            NaN                            NaN
#
#        COLLISION_ID                  VEHICLE TYPE CODE 1  \
# 0           4487052                                Sedan
# 1           4486581                                  Van
# 2           4521853  Station Wagon/Sport Utility Vehicle
# 3           4485150                                 Bike
# 4           4485355                                Sedan
# ...             ...                                  ...
# 21096       4288986  Station Wagon/Sport Utility Vehicle
# 21097       4575887  Station Wagon/Sport Utility Vehicle
# 21098       4580242                                 Taxi
# 21099       4664391                                  Bus
# 21100       4670407  Station Wagon/Sport Utility Vehicle
#
#                        VEHICLE TYPE CODE 2  \
# 0                                     Bike
# 1                                     Bike
# 2                                     Bike
# 3                                      NaN
# 4                                     Bike
# ...                                    ...
# 21096  Station Wagon/Sport Utility Vehicle
# 21097                                 Bike
# 21098                              Pedicab
# 21099                                 Bike
# 21100                               E-Bike
#
#                        VEHICLE TYPE CODE 3 VEHICLE TYPE CODE 4  \
# 0                                      NaN                 NaN
# 1                                      NaN                 NaN
# 2                                      NaN                 NaN
# 3                                      NaN                 NaN
# 4                                      NaN                 NaN
# ...                                    ...                 ...
# 21096  Station Wagon/Sport Utility Vehicle           E-Scooter
# 21097                                  NaN                 NaN
# 21098                                  NaN                 NaN
# 21099                                  NaN                 NaN
# 21100                                  NaN                 NaN
#
#       VEHICLE TYPE CODE 5
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 21096               Sedan
# 21097                 NaN
# 21098                 NaN
# 21099                 NaN
# 21100                 NaN
#
# [21101 rows x 29 columns]

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# Is spaces ok in column names? It's alright, just some pandas commands may not work

# %% [markdown]
# #### Observation 1
# Date not in date time object, but in strings. Not the best to work with for date.

# %%
type(data['CRASH DATE'][0])
# Out:
# str

# %%
data['CRASH DATE'] = pd.to_datetime(data['CRASH DATE'])

# %%
data.sort_values(by='CRASH DATE')
# Out:
#       CRASH DATE CRASH TIME    BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 13270 2020-01-02      20:42  MANHATTAN   10023.0  40.772243 -73.990005
# 13351 2020-01-02      17:35   BROOKLYN   11221.0  40.693874 -73.917770
# 13301 2020-01-02      13:30        NaN       NaN  40.714165 -74.006320
# 13348 2020-01-02      16:00  MANHATTAN   10012.0  40.725643 -73.992070
# 13324 2020-01-02      21:30  MANHATTAN   10007.0  40.711933 -74.009850
# ...          ...        ...        ...       ...        ...        ...
# 20732 2024-03-23      21:00   BROOKLYN   11201.0  40.692318 -73.989660
# 20733 2024-03-23       8:20   BROOKLYN   11211.0  40.716840 -73.956640
# 20736 2024-03-23      16:33     QUEENS   11106.0  40.760800 -73.939150
# 20737 2024-03-23      21:40   BROOKLYN   11207.0  40.680405 -73.887640
# 20735 2024-03-23       5:20  MANHATTAN   10002.0  40.723648 -73.991030
#
#                       LOCATION                    ON STREET NAME  \
# 13270  (40.772243, -73.990005)  WEST 60 STREET
# 13351   (40.693874, -73.91777)  CENTRAL AVENUE
# 13301   (40.714165, -74.00632)  CHAMBERS STREET
# 13348   (40.725643, -73.99207)  BOWERY
# 13324   (40.711933, -74.00985)                               NaN
# ...                        ...                               ...
# 20732   (40.692318, -73.98966)                               NaN
# 20733    (40.71684, -73.95664)                               NaN
# 20736     (40.7608, -73.93915)                         36 AVENUE
# 20737   (40.680405, -73.88764)                    WARWICK STREET
# 20735   (40.723648, -73.99103)               EAST HOUSTON STREET
#
#       CROSS STREET NAME                           OFF STREET NAME  ...  \
# 13270   WEST END AVENUE                                       NaN  ...
# 13351      GATES AVENUE                                       NaN  ...
# 13301               NaN                                       NaN  ...
# 13348     EAST 2 STREET                                       NaN  ...
# 13324               NaN  30        VESEY STREET                    ...
# ...                 ...                                       ...  ...
# 20732               NaN                250       JORALEMON STREET  ...
# 20733               NaN                   559       DRIGGS AVENUE  ...
# 20736         12 STREET                                       NaN  ...
# 20737  ARLINGTON AVENUE                                       NaN  ...
# 20735   CHRYSTIE STREET                                       NaN  ...
#
#        CONTRIBUTING FACTOR VEHICLE 2  CONTRIBUTING FACTOR VEHICLE 3  \
# 13270                    Unspecified                            NaN
# 13351                    Unspecified                            NaN
# 13301                    Unspecified                            NaN
# 13348                    Unspecified                            NaN
# 13324                    Unspecified                            NaN
# ...                              ...                            ...
# 20732                    Unspecified                            NaN
# 20733                    Unspecified                            NaN
# 20736                    Unspecified                            NaN
# 20737                    Unspecified                            NaN
# 20735                    Unspecified                            NaN
#
#        CONTRIBUTING FACTOR VEHICLE 4  CONTRIBUTING FACTOR VEHICLE 5  \
# 13270                            NaN                            NaN
# 13351                            NaN                            NaN
# 13301                            NaN                            NaN
# 13348                            NaN                            NaN
# 13324                            NaN                            NaN
# ...                              ...                            ...
# 20732                            NaN                            NaN
# 20733                            NaN                            NaN
# 20736                            NaN                            NaN
# 20737                            NaN                            NaN
# 20735                            NaN                            NaN
#
#        COLLISION_ID                  VEHICLE TYPE CODE 1  VEHICLE TYPE CODE 2  \
# 13270       4268270                                 Bike                  NaN
# 13351       4268207  Station Wagon/Sport Utility Vehicle                 Bike
# 13301       4271563                                Sedan                 Bike
# 13348       4268322                                Sedan                 Bike
# 13324       4271936                                Sedan                 Bike
# ...             ...                                  ...                  ...
# 20732       4712033                                Sedan                 Bike
# 20733       4712331  Station Wagon/Sport Utility Vehicle                 Bike
# 20736       4711895  Station Wagon/Sport Utility Vehicle               E-Bike
# 20737       4712173                                Sedan               E-Bike
# 20735       4712390                                Sedan                 Bike
#
#        VEHICLE TYPE CODE 3 VEHICLE TYPE CODE 4 VEHICLE TYPE CODE 5
# 13270                  NaN                 NaN                 NaN
# 13351                  NaN                 NaN                 NaN
# 13301                  NaN                 NaN                 NaN
# 13348                  NaN                 NaN                 NaN
# 13324                  NaN                 NaN                 NaN
# ...                    ...                 ...                 ...
# 20732                  NaN                 NaN                 NaN
# 20733                  NaN                 NaN                 NaN
# 20736                  NaN                 NaN                 NaN
# 20737                  NaN                 NaN                 NaN
# 20735                  NaN                 NaN                 NaN
#
# [21101 rows x 29 columns]

# %% [markdown]
# #### Observation 2
# Missingness:
# - Missing values in `BOROUGH` can be depended on the columns in `ON STREET NAME`, `CROSS STREET NAME` or `OFF STREET NAME`. However, it is complicated to recover due to so many roads in one area. This is also similar for `LATITUDE` and `LONGITUDE`.
# - We either have information for `OFF STREET NAME` or `ON STREET NAME`, and may or may not have `CROSS STREET NAME`. `OFF STREET NAME` provides the exact address if known where `ON STREET NAME` and `CROSS STREET NAME` is more of a general area.
# - Missing values in `CONTRIBUTING FACTOR VEHICLE 2/3/4/5` are misssing is due to the incident does not have that many vehicles involved.
# - Not sure about the relations between missingness of `CONTRIBUTING FACTOR VEHICLE` and `VEHICLE TYPE`.
